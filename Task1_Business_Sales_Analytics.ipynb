# %% [markdown]
# <a href="https://colab.research.google.com/github/harshinidodda27/FUTURE_DS_01/blob/main/Task1_Business_Sales_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Business Sales Performance Analytics
#
# ## Future Interns Data Science Internship
#
# ### Task 1
#
# **Intern:** Dodda Harshini

# %%
print("Hello Future Interns!")
# Out:
# Hello Future Interns!
